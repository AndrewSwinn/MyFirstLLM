# %%
import os
import pickle
from   DuckDuckBlipWalk import node

# %%
def treewalk(node_id=0, indent=0):
    for node in [node for node in results if node.parent_id == node_id]:
        print(node.id, " " * indent, node.text)
        treewalk(node.id, indent + 2)

# %%
with open(os.path.join(os.getcwd(), os.pardir, 'cat.pkl'), 'rb') as file:
    results = pickle.load(file)

# %%
len(results)
# Out:
# 8

# %%
treewalk()
# Out:
# 1  a kitten with blue eyes is sitting on a wooden bench
# 4    a small kitten sitting on a wooden bench looking at the camera - stock image
# 5    a cat with blue eyes sitting on a wooden bench
# 6    a white cat with blue eyes sitting on a wooden bench
# 7    cute kitten with glowing eyes sitting on a stump
# 8    a white cat sitting on a wooden bench
# 2  a cat with a black background
# 3  a fluffy cat sitting on a log in the grass

# %%
text = 'a small dog running through the grass'

result = [result for result in results if result.text == text]
# Out:
# 22

# %%
results[7].image
# Out:
# <PIL.Image.Image image mode=RGB size=800x533>
